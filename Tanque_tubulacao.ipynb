# %% [markdown]
# <font size="6"> **ENG 07044 - Controle de Processos Industriais / DEQUI / UFRGS** </font>
#
# <font size="5">
# Introdução -- Controle da Temperatura de um Tanque com Tubulação Longa
# </font>

# %% [markdown]
# # Importando Pacotes e Inicializando
# Praticamente esse é o conjunto de pacotes que devem ser carregados na maioria das nossas simulações.
# Boa parte dos nossos Notebooks deverão iniciar com esses comandos.

# %%
# Carregando os demais pacotes 
import matplotlib.pyplot as plt
import numpy as np
import ipywidgets as wg
import control.matlab as ml
from scipy import signal as sg
from scipy.integrate import solve_ivp

from plotly.subplots import make_subplots
import plotly.graph_objects as go

import plotly.io as pio
pio.templates.default = 'seaborn' #'plotly_dark' #seaborn' #'seaborn'
Opcoes = ['ggplot2', 'seaborn', 'simple_white', 'plotly',
         'plotly_white', 'plotly_dark', 'presentation', 'xgridoff',
         'ygridoff', 'gridon', 'none'];

# Configurando para os gráficos serem inseridos no Notebook
# %matplotlib inline

# %% [markdown]
# # Planta de Tanque de Aquecimento com Tubulação Longa -- Modelo Matemático
#
# O sistema que iremos analisar consiste em um tanque de aquecimento (similar a um chuveiro elétrico) que opera a volume constante seguido de uma tubulação longa. O objetivo de controle é a temperatura de saída dessa tubulação.
# Esquematicamente esse sistem é ilustrado na figura a seguir:
# ![image.png](attachment:50a83f89-7eac-40a3-8f14-d40da352e0f1.png)
#
# Esse planta pode ser descrita matemática por esse conjunto de equações diferencias:
#
# **Balanço de Energia no TANQUE:**
#
# $$ \frac{dT_1}{dt} = \frac{F_{in}}{V} (T_{in}-T_1) + \frac{Q_{max}}{\rho C_V V}z - \frac{UA}{\rho C_V V} (T_1 - T_{inf})$$
#
# **Balanço de Energia na Tubulação:**
#
# *a) Versão discretizada -- Sistema de **n** equações diferencias de 1ªordem em série*
#
# $$ \frac{dT_i}{dt} = \frac{F_{in}n}{Vt} (T_{i-1}-T_i) - \frac{UA_t n}{\rho C_V V_t} (T_i - T_{inf})$$
#
# N equações do tipo com $i = 1..n$
#
# *b) Versão empistonada -- Tempo Morto*
#
# $$ \theta = \frac{V_t}{F_{in}} $$
#
# o problema é calcular a perda de calor na tubulação quando se utiliza apenas o atraso de transporte, aqui vai uma aproximação grosseira:
# $$ 0 = \frac{F_{in}}{Vt} (T_1-T_f) - \frac{UA_t}{\rho C_V V_t} (T_f - T_{inf})$$
#
# $$ T_f = \frac{T_1 + \frac{UA_t}{F_{in}} T_{inf}}{1 + \frac{UA_t}{F_{in}}}$$
#
# ![image.png](attachment:1e38f02e-4fdd-4c6d-a8e4-7d41c9fd192e.png)
#
# Como nosso sistema tem similaridades com um *chuveiro elétrico* fica aqui um link para contar um pouco da história do seu surgimente -- https://canaltech.com.br/produtos/quem-inventou-o-chuveiro-eletrico-217919/![download.png](attachment:154d0a10-4165-4ef4-a60e-4cd14b6725d8.png)

# %%
# modelo só do tanque
def TanqueAquecimento(t,T1,                           # tempo e variável de estado -- seguindo o padrão do integrado
                      z=70,Fin =10,Tin =25,Tinf= 25,  # manipuladas e distúrbios -- entradas
                      V=20,Qmax=800*20,UA =200):         # parâmetros físcos que descrevem o sistema
    return(((Fin/V)*(Tin-T1)+(Qmax/V)*z/100-(UA/V)*(T1-Tinf)))

# %% [markdown]
# ## Comparando as abordagens puro atraso de transporte com primeira ordem em série

# %%
# modelo do tanque e da tubulação
UAt = 0.
def TanqueAquecimentoTubulacao(t,T,                                       # tempo e variável de estado -- seguindo o padrão do integrado
                               z=70,Fin =10,Tin =25,Tinf= 25,             # manipuladas e distúrbios -- entradas
                               V=20, Vt = 5, Qmax=800*20,UA =200, UAt = UAt):# parâmetros físcos que descrevem o sistema
    # O tamanho da discretização da tubulação é está associado ao número total de temperaturas
    # descontando um, pois a primeira temperatura corresponde a do tanque de aquecimento
    # N -- corresponde ao número total de temperaturas, ou seja, consiste na dimensão do vetor T
    
    N = np.size(T)
    return ([(Fin/V*(Tin-T[0])+(Qmax/V)*z/100-UA/V*(T[0]-Tinf))]
            + list((N-1)/Vt*(Fin*(T[0:N-1]-T[1:N])-UAt*(T[1:N]-Tinf))))

# %%
# comparando as abordagens
tq  = solve_ivp(TanqueAquecimento,[0, 3],[63.098], t_eval = np.linspace(0,3,100), rtol=1e-6 )
UAt = 0.0
tqt = solve_ivp(TanqueAquecimentoTubulacao,[0, 3],63.098*np.ones(100), t_eval = np.linspace(0,3,100), rtol=1e-6 )
plt.plot(tq.t+0.5,tq.y[0,:])
plt.plot(tqt.t,tqt.y[-1,:])
plt.grid()

# %% [markdown]
# ## Determinação da condição estacionário

# %%
UAt = 0.01
def TanqueAquecimentoTubulacao(t,T,                                       # tempo e variável de estado -- seguindo o padrão do integrado
                               z=50,Fin =10,Tin =25,Tinf= 25,             # manipuladas e distúrbios -- entradas
                               V=20, Vt = 5, Qmax=800*20,UA =200, UAt = UAt):# parâmetros físcos que descrevem o sistema
    # O tamanho da discretização da tubulação é está associado ao número total de temperaturas
    # descontando um, pois a primeira temperatura corresponde a do tanque de aquecimento
    # N -- corresponde ao número total de temperaturas, ou seja, consiste na dimensão do vetor T
    
    N = np.size(T)
    return ([(Fin/V*(Tin-T[0])+(Qmax/V)*z/100-UA/V*(T[0]-Tinf))]
            + list((N-1)/Vt*(Fin*(T[0:N-1]-T[1:N])-UAt*(T[1:N]-Tinf))))

# %%
# determinação do valor estacionário
sol = solve_ivp(TanqueAquecimentoTubulacao,[0, 3],63.098*np.ones(100), 
                t_eval = np.linspace(0,3,100),args=(50,10), rtol=1e-6 )
T0 = sol.y[:,-1]  # agora temos em T0 as temperaturas iniciais estacionárias para 50% da potência
plt.plot(sol.t,sol.y[0,:])
plt.plot(sol.t,sol.y[-1,:]);

# %% [markdown]
# # Simulação em malha aberta -- para várias perturbações

# %%
def Simulacao_MA (SYS, y0, TU, dt=0.01, Matplot = False, Plotly = False):
    
    # Armazenamento dos dados resultantes da simulação
    Tfinal = TU[-1,0] 
    
    #(Ad,Bd,Cd,Dd,dt)=sg.cont2discrete(SS_Planta(P),dt)
    # calculo do deslocamento do tempo morto (kd)
    #kd = int(round(P['TempoMorto']/dt,0))

    # Armazenamento dos dados resultantes da simulação

    TT = np.arange(start=0,stop=Tfinal+dt,step = dt, dtype='float')
    NT = np.size(TT)
    NY = np.size(y0)
    YY = np.zeros((NT,NY))
    nu = np.size(TU,1)
    UU = np.zeros((NT,nu-1))

    #x = np.zeros((3,1)) # condição inicial do modelo linear

    ii = 0    
    YY[0,:]=y0
    
    for k in np.arange(NT-1):
        
        if TT[k] >= TU[ii+1,0]:
            ii=ii+1
    
        # Definição das variáveis de entrada
        UU[k,:] = TU[ii,1:nu]
    
           
        # Armazenamento dos valores calculados
        
        sol = solve_ivp(SYS,[TT[k], TT[k+1]],YY[k,:], args = tuple(UU[k]), rtol =1e-6) #,method="RK45",max_step = dt, atol=1, rtol=1)
                        
        YY[k+1,:]=sol.y[:,-1]    
                        
                        
    #erro = yy_f-YY
    UU[k+1,:] = TU[ii,1:nu]
    
    if Matplot:
        plt.figure(figsize=(12,6))
        plt.subplot(2,1,1)    
        
        plt.plot(TT,YY[:,0])            # respota obtida em simulação discreta
        plt.plot(TT,YY[:,-1]) 
        plt.legend(['T1','Tf'])
        plt.title('Saídas ( $T_1$ e $T_f$ )')
        plt.grid()
        plt.subplot(2,1,2)
        plt.title (r'Entradas (MV e Distúrbios)')
        plt.plot(TT,UU)
        plt.legend(['z','Fin','Tin','Tinf'])
        plt.xlabel('Tempo [min]')
        plt.grid()
        
    if Plotly:
        fig = make_subplots(2,1)
        fig.add_trace(go.Scatter(name='T1', x=TT, y=YY[:,0]),1,1)
        fig.add_trace(go.Scatter(name='Tf', x=TT, y=YY[:,-1]),1,1)
        
        fig.add_trace(go.Scatter(name='z', x=TT, y=UU[:,0],line= {"shape": 'hv'}),2, 1 )        
        fig.add_trace(go.Scatter(name='Fin', x=TT, y=UU[:,1],line= {"shape": 'hv'}),2, 1 ) 
        fig.add_trace(go.Scatter(name='Tin', x=TT, y=UU[:,2],line= {"shape": 'hv'}),2, 1 ) 
        fig.add_trace(go.Scatter(name='Tinf', x=TT, y=UU[:,3],line= {"shape": 'hv'}),2, 1 ) 
        fig.update_xaxes(matches='x')
  
        
        fig.update_layout(
            height=500, 
            width = 800,
            title={
            'text': 'Saídas ( T1 e Tf )',
            'y':0.85,
            'x':0.5,
            'xanchor': 'center',
            'yanchor': 'top'},
            xaxis_title = r'Entradas (MV e Distúrbios)',
            yaxis_title='Temperaturas',
            legend_title="Variáveis",
        )
        fig.show() 
        
    return (TT,YY,UU)

# %%
# TU =np.array(
# [    # Time,   z ,  Fin , Tin, Tinf
#       [  0 ,  50 ,  10  ,  25, 25  ],
#       [  1 ,  60 ,  10  ,  25, 25  ],
#       [  2 ,  50 ,  10  ,  25, 25  ],
#       [  3 ,  50 ,  25  ,  25, 25  ],
#       [  4 ,  50 ,  10  ,  25, 10  ],
#       [  5.5 ,  50 ,  10  ,  25, 10  ],
# ])     

TU =np.array([
    # Time,   z ,  Fin , Tin, Tinf
      [  0 ,  50 ,  10  ,  25, 25  ],
      [  1 ,  60 ,  10  ,  25, 25  ],
      [ 5 ,  60 ,  10  ,  25, 25  ] # Tempo suficiente para estabilizar
])  

Simulacao_MA(TanqueAquecimentoTubulacao, T0, TU, 0.01,Plotly=True, Matplot =True);

# %% [markdown]
# Para projetar controladores de alto desempenho, é necessário primeiro obter um modelo matemático simplificado da planta. Utilizamos o modelo de **Primeira Ordem com Atraso de Transporte (FOPTD - First-Order Plus Dead Time)**, definido pela equação diferencial cuja resposta ao degrau no tempo é:
#
# $$y(t) = y_0 + K_p \Delta u \left( 1 - e^{-\frac{t - t_{degrau} - \theta}{\tau}} \right)$$
#
# Onde:
#
# - $K_p$: Ganho estático do processo.
#
# - $\tau$: Constante de tempo (inércia do sistema).
#
# - $\theta$: Tempo morto (atraso de transporte).
#
#
# ## 1. Metodologia de Extração: O Método dos Dois Pontos
#
# A função `Extrai_FOPTD` utiliza o **Método de Smith**, que consiste em amostrar a resposta do sistema em dois instantes específicos de sua variação dinâmica para isolar os parâmetros de inércia e atraso de forma analítica. Os pontos escolhidos são **28,3%** e **63,2%** da variação total da saída ($\Delta y$).
#
# ### Por que esses valores?
#
# Eles derivam das propriedades do logaritmo natural na curva exponencial:
#
# 1. **A 63,2% da subida:** O tempo transcorrido após o atraso é exatamente igual a uma constante de tempo ($\tau$), pois $1 - e^{-1} \approx 0,632$.
#
# 2. **A 28,3% da subida:** O tempo transcorrido após o atraso é exatamente igual a um terço da constante de tempo ($\tau/3$), pois $1 - e^{-1/3} \approx 0,283$.
#
#
# ## 2. Dedução Matemática do Coeficiente 1.5
#
# A origem do coeficiente $1.5$ na função não é empírica, mas sim o resultado do isolamento algébrico de $\tau$. Definimos $t_{28}$ e $t_{63}$ como os instantes de tempo (lidos no eixo das abscissas) onde a curva cruza as respectivas amplitudes:
#
# 1. $t_{63} = t_{degrau} + \theta + \tau$
#
# 2. $t_{28} = t_{degrau} + \theta + \frac{\tau}{3}$
#
#
# Para eliminar o tempo morto ($\theta$) e o instante do degrau ($t_{degrau}$) do cálculo da inércia, subtraímos a equação (2) da equação (1):
#
# $$t_{63} - t_{28} = \left( t_{degrau} + \theta + \tau \right) - \left( t_{degrau} + \theta + \frac{\tau}{3} \right)$$
#
# $$t_{63} - t_{28} = \tau - \frac{\tau}{3}$$
#
# $$t_{63} - t_{28} = \frac{2\tau}{3}$$
#
# Isolando $\tau$:
#
# $$\tau = \frac{3}{2} (t_{63} - t_{28}) = \mathbf{1.5 \cdot (t_{63} - t_{28})}$$
#
# ## 3. Equações Finais de Implementação
#
# Com a constante de tempo calculada, os demais parâmetros são extraídos diretamente:
#
# - **Ganho Estático ($K_p$):** Razão entre a variação da saída e a variação da entrada em regime permanente.
#
#     $$K_p = \frac{y_{final} - y_{inicial}}{u_{final} - u_{inicial}}$$
#
# - **Tempo Morto ($\theta$):** O atraso efetivo projetado retroativamente da curva de subida.
#
#     $$\theta = t_{63} - t_{degrau} - \tau$$
#
#
# Este método garante que a identificação seja baseada na dinâmica dominante do processo, tornando a sintonia via **Skogestad (SIMC)** nos passos seguintes extremamente precisa.

# %%
TU_Degrau = np.array([
    # Time,   z ,  Fin , Tin, Tinf
      [  0 ,  50 ,  10  ,  25, 25  ],
      [  1 ,  60 ,  10  ,  25, 25  ],
      [ 5 ,  60 ,  10  ,  25, 25  ] # Tempo suficiente para estabilizar
])

TT_ma, YY_ma, UU_ma = Simulacao_MA(TanqueAquecimentoTubulacao, T0, TU_Degrau, dt=0.01, Matplot=False, Plotly=False)

def Extrai_FOPTD(TT, YY, UU, var_idx, u_idx, t_degrau):
    """
    Identifica Kp, Tau e Theta a partir de um degrau na malha aberta.
    var_idx: Índice da variável de saída (0 para T1, -1 para Tf)
    u_idx: Índice da variável manipulada (0 para z)
    """
    # 1. Valores Iniciais (Antes do degrau) e Finais (Regime Permanente)
    idx_ini = np.searchsorted(TT, t_degrau) - 1
    y0 = YY[idx_ini, var_idx]
    u0 = UU[idx_ini, u_idx]
    
    yf = YY[-1, var_idx]
    uf = UU[-1, u_idx]
    
    # 2. Cálculo das variações e Ganho Estático (Kp)
    delta_y = yf - y0
    delta_u = uf - u0
    Kp = delta_y / delta_u
    
# 3. Normalização do vetor de resposta (Sempre crescente de 0 a 1)
    # Filtrar apenas os dados após o degrau
    TT_step = TT[idx_ini:]
    YY_step = YY[idx_ini:, var_idx]
    
    # y_norm garante um vetor monotonicamente crescente independentemente do sinal de delta_y
    y_norm = (YY_step - y0) / delta_y 
    
    # Interpolação linear para encontrar os tempos exatos na curva normalizada
    # Note que agora xp (y_norm) é sempre crescente.
    t_28 = np.interp(0.283, y_norm, TT_step)
    t_63 = np.interp(0.632, y_norm, TT_step)
    
    # 4. Cálculo de Tau e Theta
    tau = 1.5 * (t_63 - t_28)
    theta = t_63 - t_degrau - tau
    
    # Correção física: O tempo morto não pode ser negativo no mundo real
    if theta < 0: theta = 0.0 
        
    return Kp, tau, theta

# =====================================================================
# 3. EXECUÇÃO E APRESENTAÇÃO DOS DADOS
# =====================================================================
t_aplicacao_degrau = 1.0 # O degrau no z ocorre em t=1 na matriz TU_Degrau

# Extração para o Tanque (T1 -> índice 0 em YY)
Kp_1, tau_1, theta_1 = Extrai_FOPTD(TT_ma, YY_ma, UU_ma, var_idx=0, u_idx=0, t_degrau=t_aplicacao_degrau)

# Extração para a Tubulação (Tf -> índice -1 em YY)
Kp_f, tau_f, theta_f = Extrai_FOPTD(TT_ma, YY_ma, UU_ma, var_idx=-1, u_idx=0, t_degrau=t_aplicacao_degrau)

print("="*50)
print(" PARÂMETROS EXTRAÍDOS (FOPTD)")
print("="*50)
print("1. MALHA RÁPIDA: Tanque (T1)")
print(f"   Kp = {Kp_1:.4f} °C/%")
print(f"   Tau = {tau_1:.4f} min")
print(f"   Theta = {theta_1:.4f} min")
print("-" * 50)
print("2. MALHA LENTA: Tubulação (Tf)")
print(f"   Kp = {Kp_f:.4f} °C/%")
print(f"   Tau = {tau_f:.4f} min")
print(f"   Theta = {theta_f:.4f} min")
print("="*50)
# Out:
# ==================================================
#  PARÂMETROS EXTRAÍDOS (FOPTD)
# ==================================================
# 1. MALHA RÁPIDA: Tanque (T1)
#    Kp = 0.7619 °C/%
#    Tau = 0.0954 min
#    Theta = 0.0000 min
# --------------------------------------------------
# 2. MALHA LENTA: Tubulação (Tf)
#    Kp = 0.6901 °C/%
#    Tau = 0.1174 min
#    Theta = 0.4896 min
# ==================================================

# %% [markdown]
# # Malha Feedback (retroalimentada ou realimentada)
# ![image.png](attachment:8d5a0fef-1ecc-4428-ad98-12117c970bb9.png)

# %%
def PID_p2(SP, PV,k,I_int,D_int, dt, Method = 'Backward', Kp=10.0, Ti=50.0, Td=1.0, b=1.,c=0.0, 
           N=10., U_bias = 0., Umin = -100.,Umax = 100.):
    # PID -- posicional implementation   
    # Para sistemas não lineares com ação integral e b!=1 inicializar I_int =  Kp*Yset_bias*(1-b)    
    # The approximation of the derivative term are stable only when abs(ad)<1. 
    # The forward difference approximation requires that Td>N*dt/2, i.e., the 
    # approximation becomes unstable for small values of Td. The other approximation
    # are stable for all values of Td. 
    
    # Autor: Jorge Otávio Trierweiler -- jorge.trierweiler@ufrgs.br
    
    if Method == 'Backward':
        b1 = Kp*dt/Ti if Ti != 0 else 0.0
        b2 = 0.0
        ad = Td/(Td+N*dt)
        bd = Kp*Td*N/(Td+N*dt)
    elif Method == 'Forward':
        b1 = 0.0
        b2 = Kp*dt/Ti  if Ti!=0 else 0.0
        ad = 1-N*dt/Td if Td!=0 else 0.0
        bd = Kp*N   
    elif Method == 'Tustin':
        b1 = Kp*dt/2/Ti if Ti!=0 else 0.0
        b2 = b1
        ad = (2*Td-N*dt)/(2*Td+N*dt)
        bd = 2*Kp*Td*N/(2*Td+N*dt)   
    elif Method == 'Ramp':
        b1 = Kp*dt/2/Ti if Ti!=0 else 0.0
        b2 = b1
        ad = np.exp(-N*dt/Td) if Td !=0 else 0.0
        bd = Kp*Td*(1-ad)/dt
        
    # Derivative Action 
    D  = ad*D_int+bd*((c*SP[k]-PV[k])-(c*SP[k-1]-PV[k-1]))
    
    # Integral action
    
    II = b1*(SP[k]-PV[k])+b2*(SP[k-1]-PV[k-1])
    #II = Kp*dt/Ti*(SP[k]-PV[k]) if Ti!=0 else 0.0
    I = I_int + II                         
   
     
    # calculate the PID output
    P = Kp * (b*SP[k]-PV[k])
       
    Uop = U_bias + P + I + D

    # implement anti-reset windup

    if Uop < Umin:
        II = 0.0      # no caso de saturação -- diminuindo o valor integrado a mais
        Uop = Umin
    if Uop > Umax:
        II = 0.0
        Uop = Umax
    
        
    # return the controller output and PID terms
    return np.array([ Uop, I_int+II, D])

# %%
TU =np.array(
[    # Time,   SP ,  Fin , Tin, Tinf
      [  0 ,  63 ,  10  ,  25, 25  ],
      [  1 ,  70 ,  10  ,  25, 25  ],
      [  2 ,  60 ,  10  ,  25, 25  ],
      [  3 ,  60 ,  20  ,  25, 25  ],
      [  4 ,  60 ,  20  ,  10, 10  ],
      [  5 ,  60 ,  20  ,  10, 10  ],
])      


def Simulacao_MF (SYS, y0, TU, CV =0 ,                      # escolha do modelo, condição inicial, padrão de perturbação e CV (variável controlada)
                  Kp=2, Ti=0.4, Td=0, b=1, U_bias=50,      # parâmetros de ajuste do controlador 
                  Ruido = 0.005,  dt=0.01, Matplot = False, Plotly = False ):# dados complementares
    
    # Armazenamento dos dados resultantes da simulação
    Tfinal = TU[-1,0] 
    
    #(Ad,Bd,Cd,Dd,dt)=sg.cont2discrete(SS_Planta(P),dt)
    # calculo do deslocamento do tempo morto (kd)
    #kd = int(round(P['TempoMorto']/dt,0))

    # Armazenamento dos dados resultantes da simulação

   
    Yset_bias = y0[CV]
    
    TT = np.arange(start=0,stop=Tfinal+dt,step = dt, dtype='float')
    NT = np.size(TT)
    NY = np.size(y0)
    YY = np.zeros((NT,NY))
    nu = np.size(TU,1)
    UU = np.zeros((NT,nu-1))
    SP = np.zeros_like(TT)
    PV = np.ones_like(TT)*Yset_bias
    Noise = np.random.normal(0, Ruido, len(TT))
    #x = np.zeros((3,1)) # condição inicial do modelo linear
    

    ii = 0    
    
    D_int = 0.0  
    I_int = Kp*Yset_bias*(1-b)
    
    YY[0,:]=y0
      
    
    for k in np.arange(NT-1):
        
        if TT[k] >= TU[ii+1,0]:
            ii=ii+1
    
        # Definição do setpoint e do distúrbio na carga
        UU[k,:] = TU[ii,1:nu]
    
        SP[k] = TU[ii,1]
         
        PV[k]=YY[k,CV]+Noise[k]    
        # Armazenamento dos valores calculados
        uu = PID_p2(SP,PV,k,I_int, D_int, dt, Method ='Backward',
                Kp=Kp,Ti=Ti,Td=Td,N=10,b=b, 
                Umin=0, Umax=100, U_bias = U_bias)
        Uop   = uu[0]
        I_int = uu[1]
        D_int = uu[2]
        
        # Definição do setpoint e do distúrbio na carga
        UU[k,0] = Uop
    
        sol = solve_ivp(SYS,[TT[k], TT[k+1]],YY[k,:], args = tuple(UU[k]), rtol =1e-6) #,method="RK45",max_step = dt, atol=1, rtol=1)
                        
        YY[k+1,:]=sol.y[:,-1]    
                        
                        
    #erro = yy_f-YY
    
    UU[k+1,:] = TU[ii,1:nu]
    UU[k+1,0] = Uop
    SP[k+1] = TU[ii,1]
    
    if Matplot:
        plt.figure(figsize=(12,6))
        plt.subplot(2,1,1)    
        
        plt.plot(TT,YY[:,0])            # respota obtida em simulação discreta
        plt.plot(TT,YY[:,-1]) 
        plt.plot(TT,SP)
        plt.title('Saídas -- ($T_1$. $T_f$ e $SP$)')
        plt.legend(['T1','Tf','SP'])
        #plt.plot(r['time'],'y']) # resposta anterior -- rodando tudo de uma só vez
        plt.grid()
        plt.subplot(2,1,2)
        plt.plot(TT,UU)
        plt.title('Entradas (MV e Distúrbios)')
        plt.legend(['z','Fin','Tin','Tinf'])
        plt.xlabel('Tempo [min]')
        plt.grid()
        
    if Plotly:
        fig = make_subplots(2,1)
        fig.add_trace(go.Scatter(name='T1', x=TT, y=YY[:,0]),1,1)
        fig.add_trace(go.Scatter(name='Tf', x=TT, y=YY[:,-1]),1,1)
        fig.add_trace(go.Scatter(name='SP', x=TT, y=SP,line= {"shape": 'hv'}),1,1)
        
        fig.add_trace(go.Scatter(name='z', x=TT, y=UU[:,0],line= {"shape": 'hv'}),2, 1 )        
        fig.add_trace(go.Scatter(name='Fin', x=TT, y=UU[:,1],line= {"shape": 'hv'}),2, 1 ) 
        fig.add_trace(go.Scatter(name='Tin', x=TT, y=UU[:,2],line= {"shape": 'hv'}),2, 1 ) 
        fig.add_trace(go.Scatter(name='Tinf', x=TT, y=UU[:,3],line= {"shape": 'hv'}),2, 1 ) 
        fig.update_xaxes(matches='x')
  
        
        fig.update_layout(
            height=500, 
            width = 800,
            title={
            'text': 'Saídas ( T1 e Tf )',
            'y':0.85,
            'x':0.5,
            'xanchor': 'center',
            'yanchor': 'top'},
            xaxis_title = r'Entradas (MV e Distúrbios)',
            yaxis_title='Temperaturas',
            legend_title="Variáveis",
        )
        fig.show() 
     
    return (TT,YY,UU)

# %% [markdown]
# # Projeto e Sintonia dos Controladores SISO ($T_1$ e $T_f$)
#
# Para o ajuste dos controladores PID individuais, utilizou-se o **Método Vapt Vupt**, uma variação pragmática e simplificada do método **SIMC (Skogestad Internal Model Control)**. Este método baseia-se nos parâmetros do modelo de primeira ordem com tempo morto (FOPTD) obtidos na etapa de identificação.
#
# ## 1. Fundamentação Matemática
#
# As equações base para o cálculo dos parâmetros do controlador são:
#
# - **Ganho do Controlador ($K_c$):**
#
#     $$K_c = \frac{1}{K_p} \cdot \left( \frac{\tau}{\tau_c + \theta} \right)$$
#
# - **Tempo Integral ($T_i$):**
#
#     $$T_i = \min(\tau, 4(\tau_c + \theta))$$
#
# - **Parâmetro de Agressividade ($\tau_c$):** Define a velocidade da resposta em malha fechada.
#
#     - Resposta Rápida: $\tau_c = \frac{1}{3}(\tau + \theta)$
#
#     - Resposta Suave: $\tau_c = (\tau + \theta)$
#
#
# ---
#
# ## 2. Memorial de Cálculo
#
# ### A) Malha do Tanque ($T_1$) - [Ref. Exercício 1.1.1]
#
# Esta malha controla a temperatura interna do tanque, que possui resposta rápida e ausência de atraso de transporte significativo.
#
# - **Dados FOPTD:** $K_p = 0.7619$, $\tau = 0.0954$, $\theta = 0.0000$.
#
# - **Estratégia:** Adotou-se uma sintonia suave para evitar desgaste excessivo do atuador, escolhendo $\tau_c = \tau = 0.0954$.
#
# - **Cálculo $K_c$:**
#
#     $$K_c = \frac{1}{0.7619} \cdot \left( \frac{0.0954}{0.0954 + 0} \right) = \mathbf{1.312}$$
#
# - **Cálculo $T_i$:** Como $\theta=0$, o tempo integral anula o polo da planta:
#
#     $$T_i = \tau = \mathbf{0.0954 \text{ min}}$$
#
#
# ### B) Malha da Tubulação ($T_f$) - [Ref. Exercício 1.1.2]
#
# Esta malha controla a temperatura na extremidade da tubulação, enfrentando um atraso de transporte dominante (tempo morto massivo).
#
# - **Dados FOPTD:** $K_p = 0.6901$, $\tau = 0.1174$, $\theta = 0.4896$.
#
# - **Estratégia:** Em sistemas onde $\theta > \tau$ (atraso dominante), a estabilidade exige que a agressividade seja limitada pelo tempo morto. Adotou-se $\tau_c = \theta = 0.4896$.
#
# - **Cálculo $K_c$:**
#
#     $$K_c = \frac{1}{0.6901} \cdot \left( \frac{0.1174}{0.4896 + 0.4896} \right) = 1.449 \cdot 0.1199 = \mathbf{0.173}$$
#
# - **Cálculo $T_i$:** Aplicação da regra de restrição para evitar _windup_ e lentidão excessiva:
#
#     $$T_i = \min(0.1174, 4(0.4896 + 0.4896)) \implies \min(0.1174, 3.91) = \mathbf{0.1174 \text{ min}}$$
#
#
# ---
#
# Este ajuste evidencia que a malha $T_f$ exige um ganho significativamente menor para manter a estabilidade operacional frente ao atraso de 50 metros de tubulação, justificando a necessidade de uma estratégia em cascata para melhorar o desempenho regulatório.

# %%
TU =np.array(
[    # Time,   SP ,  Fin , Tin, Tinf
      [  0 ,  63 ,  10  ,  25, 25  ],
      [  3,  70 ,  10  ,  25, 25  ],
      [  6 ,  60 ,  10  ,  25, 25  ],
      [  9 ,  60 ,  20  ,  25, 25  ],
      [  12 ,  60 ,  10  ,  10, 25  ],
      [  15 ,  60 ,  10  ,  10, 10  ],
      [  18,   60,   10  ,  40, 20  ],
      [  22,   60,   10  ,  40, 20  ],
])        
print("A executar Simulação SISO SEara o Tanque (T1) e Tubulação (Tf)...")
Simulacao_MF (TanqueAquecimentoTubulacao, T0, TU, CV =-1, Kp=1,Ti=0.3,Td=0.1,b=1,
              Ruido = 0.05, U_bias=50, dt=0.01, Plotly = True );

print("A executar Simulação SISO para o Tanque (T1)...")
TT_1, YY_1, UU_1 = Simulacao_MF(
    TanqueAquecimentoTubulacao, 
    T0, 
    TU, 
    CV=0,             # Índice 0 aponta para a temperatura no tanque (T1)
    Kp=(1/Kp_1)*(tau_1/(tau_1+theta_1)) ,#1.312
    Ti=min(tau_1, 4 * (tau_1 + theta_1)) ,  #0.0954 
    Td=0.0, 
    b=1.0, 
    Ruido=0.005, 
    U_bias=50, 
    dt=0.01, 
    Plotly=True 
)


print("A executar Simulação SISO para a Tubulação (Tf)...")
TT_f, YY_f, UU_f = Simulacao_MF(
    TanqueAquecimentoTubulacao, 
    T0, 
    TU, 
    CV=-1,            # Índice -1 aponta para a temperatura na extremidade da tubulação (Tf)
    Kp=(1/Kp_f)*(tau_f/(theta_f+theta_f)) , #0.173 
    Ti=min(tau_f, 4 * (tau_f + theta_f)) ,  #0.1174 
    Td=0.0, 
    b=1.0, 
    Ruido=0.005, 
    U_bias=50, 
    dt=0.01, 
    Plotly=True 
)
# Out:
# A executar Simulação SISO SEara o Tanque (T1) e Tubulação (Tf)...
# A executar Simulação SISO para o Tanque (T1)...
# A executar Simulação SISO para a Tubulação (Tf)...

# %%
def wg_MF (Kp=0.91,Ti=0.57,Td=0.0, b=1., CV_txt = 'T1'):
    CV = -1
    if CV_txt =='T1':
        CV = 0
    Simulacao_MF (TanqueAquecimentoTubulacao, T0, TU, CV =CV,Kp=Kp,Ti=Ti,Td=Td,b=b,
              Ruido = 0.005, U_bias=50, dt=0.051, Plotly = True );

# %%
wg.interact(wg_MF,Kp=(0.01,5), Ti=(0.01, 2.,0.005), Td =(0.0, 3), b=(0.01,4), CV_txt = ['T1','Tf']);
# Out:
# interactive(children=(FloatSlider(value=0.91, description='Kp', max=5.0, min=0.01), FloatSlider(value=0.57, de…

# %% [markdown]
# # Malha Cascata
# ![image.png](attachment:2b6ec445-3fac-4634-98ac-d69bc4d8580b.png)

# %%
TU =np.array(
[    # Time,  SP , Fin , Tin, Tinf
      [  0 ,  63 ,   10  ,  25, 25  ],
      [  1 ,  70 ,  10  ,  25, 25  ],
      [  2 ,  60 ,  10  ,  25, 25  ],
      [  3 ,  60 ,  20  ,  25, 25  ],
      [  4 ,  60 ,  20  ,  10, 10  ],
      [  5 ,  60 ,  20  ,  10, 10  ],
])      


def Simulacao_MF_Cascata (SYS, y0, TU, Kp=[1,2.41],Ti=[0.6,0.1],Td=[0,0],b=[1,1], 
                          Ruido = 0.005, U_bias=50, dt=0.01,  Matplot = False, Plotly = False ):
    
    # Armazenamento dos dados resultantes da simulação
    Tfinal = TU[-1,0] 
    
    #(Ad,Bd,Cd,Dd,dt)=sg.cont2discrete(SS_Planta(P),dt)
    # calculo do deslocamento do tempo morto (kd)
    #kd = int(round(P['TempoMorto']/dt,0))

    # Armazenamento dos dados resultantes da simulação

   
    Yset_bias = y0[[-1,0]]
    
    TT = np.arange(start=0,stop=Tfinal+dt,step = dt, dtype='float')
    NT = np.size(TT)
    NY = np.size(y0)
    YY = np.zeros((NT,NY))
    nu = np.size(TU,1)
    UU = np.zeros((NT,nu-1))
    SP0 = np.zeros_like(TT)
    SP1 = np.zeros_like(TT)
    PV0 = np.ones_like(TT)*Yset_bias[0]
    PV1 = np.ones_like(TT)*Yset_bias[1]
    Noise = np.random.normal(0, Ruido, len(TT))
    #x = np.zeros((3,1)) # condição inicial do modelo linear
    

    ii = 0    
    
    D_int0 = 0.0  
    I_int0 = Kp[0]*Yset_bias[0]*(1-b[0])
    
    D_int1 = 0.0  
    I_int1 = Kp[1]*Yset_bias[1]*(1-b[1])
    
    YY[0,:]=y0
      
    
    for k in np.arange(NT-1):
        
        if TT[k] >= TU[ii+1,0]:
            ii=ii+1
    
        # Definição do setpoint e do distúrbio na carga
        UU[k,:] = TU[ii,1:nu]
    
        SP0[k] = TU[ii,1]
         
        PV0[k]=YY[k,-1]+Noise[k]  
        PV1[k]=YY[k,0] +Noise[k]
        # Armazenamento dos valores calculados
        uu = PID_p2(SP0,PV0,k,I_int0, D_int0, dt, Method ='Backward',
                Kp=Kp[0],Ti=Ti[0],Td=Td[0],N=10,b=b[0], 
                Umin=0, Umax=1000, U_bias = Yset_bias[1])
        SP1[k]   = uu[0]
        I_int0 = uu[1]
        D_int0 = uu[2]
        
        uu = PID_p2(SP1,PV1,k,I_int1, D_int1, dt, Method ='Backward',
                Kp=Kp[1],Ti=Ti[1],Td=Td[1],N=10,b=b[1], 
                Umin=0, Umax=100, U_bias = U_bias)
        Uop    = uu[0]
        I_int1 = uu[1]
        D_int1 = uu[2]
        
        # Definição do setpoint e do distúrbio na carga
        UU[k,0] = Uop
    
        sol = solve_ivp(SYS,[TT[k], TT[k+1]],YY[k,:], args = tuple(UU[k]), rtol =1e-6) #,method="RK45",max_step = dt, atol=1, rtol=1)
                        
        YY[k+1,:]=sol.y[:,-1]    
                        
                        
    #erro = yy_f-YY
    
    UU[k+1,:] = TU[ii,1:nu]
    UU[k+1,0] = Uop
    SP0[k+1] = TU[ii,1]
    SP1[k+1] = SP1[k]
    if Matplot:
        plt.figure(figsize=(12,6))
        plt.subplot(2,1,1)    
        
        plt.plot(TT,YY[:,0])            # respota obtida em simulação discreta
        plt.plot(TT,YY[:,-1]) 
        plt.plot(TT,SP0)
        plt.plot(TT,SP1)
        plt.title('Saídas -- ($T_1$. $T_f$, $SP_1$ e $SP_2$)')
        plt.legend(['T1','Tf','$SP_f$','$SP_1$'])
        #plt.plot(r['time'],'y']) # resposta anterior -- rodando tudo de uma só vez
        plt.grid()
        plt.subplot(2,1,2)
        plt.plot(TT,UU)
        plt.title('Entradas  (MV e distúrbios)')
        plt.xlabel('Tempo [min]')
        plt.legend(['z','Fin','Tin','Tinf'])
        plt.grid()
        
    if Plotly:
        fig = make_subplots(2,1)
        fig.add_trace(go.Scatter(name='T1', x=TT, y=YY[:,0]),1,1)
        fig.add_trace(go.Scatter(name='Tf', x=TT, y=YY[:,-1]),1,1)
        fig.add_trace(go.Scatter(name='SPf', x=TT, y=SP0,line= {"shape": 'hv'}),1,1)
        fig.add_trace(go.Scatter(name='SP1', x=TT, y=SP1,line= {"shape": 'hv'}),1,1)
        
        fig.add_trace(go.Scatter(name='z', x=TT, y=UU[:,0],line= {"shape": 'hv'}),2, 1 )        
        fig.add_trace(go.Scatter(name='Fin', x=TT, y=UU[:,1],line= {"shape": 'hv'}),2, 1 ) 
        fig.add_trace(go.Scatter(name='Tin', x=TT, y=UU[:,2],line= {"shape": 'hv'}),2, 1 ) 
        fig.add_trace(go.Scatter(name='Tinf', x=TT, y=UU[:,3],line= {"shape": 'hv'}),2, 1 ) 
        fig.update_xaxes(matches='x')
  
        
        fig.update_layout(
            height=500, 
            width = 800,
            title={
            'text': 'Saídas ( T1 e Tf )',
            'y':0.85,
            'x':0.5,
            'xanchor': 'center',
            'yanchor': 'top'},
            xaxis_title = r'Entradas (MV e Distúrbios)',
            yaxis_title='Temperaturas',
            legend_title="Variáveis",
        )
        fig.show() 

        
    return (TT,YY,UU)

# %%
TU =np.array(
[    # Time,   SP ,  Fin , Tin, Tinf
      [  0 ,  63 ,  10  ,  25, 25  ],
      [  3,  70 ,  10  ,  25, 25  ],
      [  6 ,  60 ,  10  ,  25, 25  ],
      [  9 ,  60 ,  20  ,  25, 25  ],
      [  12 ,  60 ,  10  ,  10, 25  ],
      [  15 ,  60 ,  10  ,  10, 10  ],
      [  18,   60,   10  ,  40, 20  ],
      [  22,   60,   10  ,  40, 20  ],
])        
Simulacao_MF_Cascata (TanqueAquecimentoTubulacao, T0, TU, Kp=[0.795,5],Ti=[0.5,5],Td=[0.01,0],b=[2,1], Ruido = 0.05, U_bias=50, dt=0.01, Plotly = True );

print("A executar Simulação em Cascata (Arquitetura 2-DOF)...")

TT_c, YY_c, UU_c = Simulacao_MF_Cascata(
    TanqueAquecimentoTubulacao, 
    T0, 
    TU, 
    Kp=[0.450, 1.312],   # [K_c Mestre, K_c Escravo]
    Ti=[0.350, 0.0954],  # [T_i Mestre, T_i Escravo]
    Td=[0.0, 0.0], 
    b=[0.5, 1.0],        # Ponderação 2-DOF: [b Mestre, b Escravo]
    Ruido=0.005, 
    U_bias=50, 
    dt=0.01, 
    Plotly=True 
)

print("A executar Simulação em Cascata (Arquitetura Otimizada)...")

TT_c, YY_c, UU_c = Simulacao_MF_Cascata(
    TanqueAquecimentoTubulacao, 
    T0, 
    TU, 
    Kp=[0.170, 1.312],   # [K_c Mestre, K_c Escravo]
    Ti=[0.165, 0.0954],  # [T_i Mestre, T_i Escravo]
    Td=[0.0, 0.0], 
    b=[0.4, 1.0],        # [b Mestre, b Escravo]
    Ruido=0.005, 
    U_bias=50, 
    dt=0.01, 
    Plotly=True 
)
# Out:
# A executar Simulação em Cascata (Arquitetura 2-DOF)...
# A executar Simulação em Cascata (Arquitetura Otimizada)...

# %% [markdown]
# ![image.png](attachment:a6100a14-758b-4c8e-8774-827bd915bd95.png)

# %%
def wg_MF_cascata(Kp_ext = 1., Ti_ext = 0.21, b_ext = 1 , Kp_in =7.2 , Ti_in = 2.30, b_in = 0.5):
    Simulacao_MF_Cascata (TanqueAquecimentoTubulacao, T0, TU, Kp=[Kp_ext,Kp_in],Ti=[Ti_ext,Ti_in],Td=[0.0,0],b=[b_ext,b_in], Ruido = 0.005, U_bias=50, dt=0.01, Plotly = True )

# %%
wg.interact(wg_MF_cascata, Kp_ext = (0.01, 2), Ti_ext = (0.01, 2,0.01), b_ext =(0.01,3) , Kp_in =(0.01, 10) , Ti_in =(0.01,10) , b_in = (0.01,3));
# Out:
# interactive(children=(FloatSlider(value=1.0, description='Kp_ext', max=2.0, min=0.01), FloatSlider(value=0.21,…

# %% [markdown]
# # Malha Antecipativa -- Feedforward + FeedBack
# ![image.png](attachment:8b6ae52d-a6fa-429e-b299-d7eadb09e8e7.png)

# %% [markdown]
# Aqui vamos implementar um controlador **Antecipativo** tendo a temperatura de alimentação como distúrbio medido. Para projetar as ações de controle faremos uso do modelo
# $$ \frac{dT_1}{dt} = \frac{F_{in}}{V} (T_{in}-T_1) + \frac{Q_{max}}{\rho C_V V}z - \frac{UA}{\rho C_V V} (T_1 - T_{inf})$$
#
# Agora vamos calcular o valor da potência necessária para compensar uma tempetur de entrada, a qual é dada por:
# $$ 0 = \frac{F_{in}}{V} (T_{in}-T_1) + \frac{Q_{max}}{\rho C_V V}z $$
# que isolando para z  chegamos a expressão base da implementação:
# $$ z = \frac{F_{in} \rho C_V}{Q_{max}} (T_1-T_{in})$$
# A implementação será através da atualização do valor do U_bias do controlador.

# %%
TU =np.array(
[    # Time,   SP ,  Fin , Tin, Tinf
      [  0 ,  63 ,  10  ,  25, 25  ],
      [  1 ,  70 ,  10  ,  25, 25  ],
      [  2 ,  60 ,  10  ,  25, 25  ],
      [  3 ,  60 ,  20  ,  25, 25  ],
      [  4 ,  60 ,  20  ,  10, 10  ],
      [  5 ,  60 ,  20  ,  10, 10  ],
])      


def Simulacao_MF_FF (SYS, y0, TU, CV =-1 ,                # escolha do modelo, condição inicial, padrão de perturbação e CV (variável controlada)
                  Kp=2, Ti=0.4, Td=0, b=1, U_bias=50,      # parâmetros de ajuste do controlador 
                  Ruido = 0.005,  dt=0.01, Matplot = False, Plotly = False ):# dados complementares
    
    # Armazenamento dos dados resultantes da simulação
    Tfinal = TU[-1,0] 
    
    #(Ad,Bd,Cd,Dd,dt)=sg.cont2discrete(SS_Planta(P),dt)
    # calculo do deslocamento do tempo morto (kd)
    #kd = int(round(P['TempoMorto']/dt,0))

    # Armazenamento dos dados resultantes da simulação

   
    Yset_bias = y0[CV]
    
    TT = np.arange(start=0,stop=Tfinal+dt,step = dt, dtype='float')
    NT = np.size(TT)
    NY = np.size(y0)
    YY = np.zeros((NT,NY))
    nu = np.size(TU,1)
    UU = np.zeros((NT,nu-1))
    SP = np.zeros_like(TT)
    PV = np.ones_like(TT)*Yset_bias
    Noise = np.random.normal(0, Ruido, len(TT))
    #x = np.zeros((3,1)) # condição inicial do modelo linear
    

    ii = 0    
    
    D_int = 0.0  
    I_int = Kp*Yset_bias*(1-b)
    
    YY[0,:]=y0
      
    
    for k in np.arange(NT-1):
        
        if TT[k] >= TU[ii+1,0]:
            ii=ii+1
    
        # Definição do setpoint e do distúrbio na carga
        UU[k,:] = TU[ii,1:nu]
    
        SP[k] = TU[ii,1]
         
        PV[k]=YY[k,CV]+Noise[k]    
        
        #ação antecipativa
        z_FF = 5/80*(25-TU[ii,3])        
        
        # Armazenamento dos valores calculados
        uu = PID_p2(SP,PV,k,I_int, D_int, dt, Method ='Backward',
                Kp=Kp,Ti=Ti,Td=Td,N=10,b=b, 
                Umin=0, Umax=100, U_bias = U_bias + z_FF)
        Uop   = uu[0]
        I_int = uu[1]
        D_int = uu[2]
        
        # Definição do setpoint e do distúrbio na carga
        UU[k,0] = Uop 
    
        sol = solve_ivp(SYS,[TT[k], TT[k+1]],YY[k,:], args = tuple(UU[k]), rtol =1e-6) #,method="RK45",max_step = dt, atol=1, rtol=1)
                        
        YY[k+1,:]=sol.y[:,-1]    
                        
                        
    #erro = yy_f-YY
    
    UU[k+1,:] = TU[ii,1:nu]
    UU[k+1,0] = Uop
    SP[k+1] = TU[ii,1]
    
    if Matplot:
        plt.figure(figsize=(12,6))
        plt.subplot(2,1,1)    
        
        plt.plot(TT,YY[:,0])            # respota obtida em simulação discreta
        plt.plot(TT,YY[:,-1]) 
        plt.plot(TT,SP)
        plt.title('Saídas -- ($T_1$. $T_f$ e $SP$)')
        plt.legend(['T1','Tf','SP'])
        #plt.plot(r['time'],'y']) # resposta anterior -- rodando tudo de uma só vez
        plt.grid()
        plt.subplot(2,1,2)
        plt.plot(TT,UU)
        plt.title('Entradas (MV e Distúrbios)')
        plt.legend(['z','Fin','Tin','Tinf'])
        plt.xlabel('Tempo [min]')
        plt.grid()
        
    if Plotly:
        fig = make_subplots(2,1)
        fig.add_trace(go.Scatter(name='T1', x=TT, y=YY[:,0]),1,1)
        fig.add_trace(go.Scatter(name='Tf', x=TT, y=YY[:,-1]),1,1)
        fig.add_trace(go.Scatter(name='SP', x=TT, y=SP,line= {"shape": 'hv'}),1,1)
        
        fig.add_trace(go.Scatter(name='z', x=TT, y=UU[:,0],line= {"shape": 'hv'}),2, 1 )        
        fig.add_trace(go.Scatter(name='Fin', x=TT, y=UU[:,1],line= {"shape": 'hv'}),2, 1 ) 
        fig.add_trace(go.Scatter(name='Tin', x=TT, y=UU[:,2],line= {"shape": 'hv'}),2, 1 ) 
        fig.add_trace(go.Scatter(name='Tinf', x=TT, y=UU[:,3],line= {"shape": 'hv'}),2, 1 ) 
        fig.update_xaxes(matches='x')
  
        
        fig.update_layout(
            height=500, 
            width = 800,
            title={
            'text': 'Saídas ( T1 e Tf )',
            'y':0.85,
            'x':0.5,
            'xanchor': 'center',
            'yanchor': 'top'},
            xaxis_title = r'Entradas (MV e Distúrbios)',
            yaxis_title='Temperaturas',
            legend_title="Variáveis",
        )
        fig.show() 

        
    
        
    return (TT,YY,UU)

# %%
TU =np.array(
[    # Time,   SP ,  Fin , Tin, Tinf
      [  0 ,  63 ,  10  ,  25, 25  ],
      [  3,  70 ,  10  ,  25, 25  ],
      [  6 ,  60 ,  10  ,  25, 25  ],
      [  9 ,  60 ,  20  ,  25, 25  ],
      [  12 ,  60 ,  10  ,  10, 25  ],
      [  15 ,  60 ,  10  ,  30, 25  ],
      [  18,   60,   10  ,  10, 25  ],
      [  22,   60,   10  ,  10, 25  ],
])      


Simulacao_MF_FF (TanqueAquecimentoTubulacao, T0, TU, CV =-1, Kp=1,Ti=0.3,Td=0.1,b=1,
              Ruido = 0.05, U_bias=50, dt=0.01, Plotly = True );

# %% [markdown]
# Controlador sem Feedforward
# ![image.png](attachment:d64c89ad-803a-4f5a-9098-056fb9117725.png)
